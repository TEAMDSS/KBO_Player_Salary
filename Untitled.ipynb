# %%
# import package
import pandas as pd
import time
import pickle
from selenium import webdriver
import glob
import os

# %%
api_delay_term = 3

# %%
def crawling_team_name():
    url = "http://www.koreabaseball.com/Record/Player/HitterBasic/Basic1.aspx"
    driver = webdriver.PhantomJS()
    driver.get(url)
    teams = driver.find_element_by_css_selector('#cphContainer_cphContents_ddlTeam_ddlTeam').\
            find_elements_by_css_selector('option')
    team_df = pd.DataFrame(columns=[
            'team_name'
        ])
    for team in teams:
        tmp_dict = {
            'team' : team.text
        }
        team_df.loc[len(team_df)] = tmp_dict
    return team_df

# %%
# crawling_hitter_basic
def crawling_hitter_basic(season_id, team_id):
    """
    season_id = 0 ~ 34
    team_id = 1 ~ 10
    ------------------------------------------------------------------------------------
    <season_id>
    0 : 1982 ~ 34 : 2016
    
    <team_id>
    1 : Nexen heroes
    2 : Doosan
    3 : Lotte
    4 : Samsung
    5 : Hanhwa
    6 : KIA
    7 : KT
    8 : LG twins
    9 : NC dinos
    10 : SK wyberns
    """
    
    url = "http://www.koreabaseball.com/Record/Player/HitterBasic/Basic1.aspx"
    driver = webdriver.PhantomJS()
    driver.get(url)
    
    # click season
    driver.find_element_by_css_selector('#cphContainer_cphContents_ddlSeason_ddlSeason').\
            find_elements_by_css_selector('option')[season_id].click()
    time.sleep(api_delay_term)
    # click team
    driver.find_element_by_css_selector('#cphContainer_cphContents_ddlTeam_ddlTeam').\
            find_elements_by_css_selector('option')[team_id].click()
    time.sleep(api_delay_term)
    elements = driver.find_elements_by_css_selector(".record_result tr")
    elements = elements[1:len(elements)+1]
    
    hitter_basic_df = pd.DataFrame(columns=[
        'rank', 'name', 'team', 'avg', 'g', 'pa', 'ab', 'r', 'h', '2b',
        '3b', 'hr', 'tb', 'rbi', 'sac', 'sf'
    ])
    
    for element in elements:
        tmp_dict  = {
            'rank' : element.find_elements_by_css_selector('td')[0].text,
            'name' : element.find_elements_by_css_selector('td')[1].text,
            'team' : element.find_elements_by_css_selector('td')[2].text,
            'avg' : element.find_elements_by_css_selector('td')[3].text,
            'g' : element.find_elements_by_css_selector('td')[4].text,
            'pa' : element.find_elements_by_css_selector('td')[5].text,
            'ab' : element.find_elements_by_css_selector('td')[6].text,
            'r' : element.find_elements_by_css_selector('td')[7].text,
            'h' : element.find_elements_by_css_selector('td')[8].text,
            '2b' : element.find_elements_by_css_selector('td')[9].text,
            '3b' : element.find_elements_by_css_selector('td')[10].text,
            'hr' : element.find_elements_by_css_selector('td')[11].text,
            'tb' : element.find_elements_by_css_selector('td')[12].text,
            'rbi' : element.find_elements_by_css_selector('td')[13].text,
            'sac' : element.find_elements_by_css_selector('td')[14].text,
            'sf' : element.find_elements_by_css_selector('td')[15].text,
        }
        hitter_basic_df.loc[len(hitter_basic_df)] = tmp_dict
    return hitter_basic_df

# %%
# crawling_hitter_detail
def crawling_hitter_detail(season_id, team_id):
    """
    season_id = 0 ~ 34
    team_id = 1 ~ 10
    ------------------------------------------------------------------------------------
    <season_id>
    0 : 1982 ~ 34 : 2016
    
    <team_id>
    1 : Nexen heroes
    2 : Doosan
    3 : Lotte
    4 : Samsung
    5 : Hanhwa
    6 : KIA
    7 : KT
    8 : LG twins
    9 : NC dinos
    10 : SK wyberns
    """
    
    url = "http://www.koreabaseball.com/Record/Player/HitterBasic/Detail1.aspx"
    driver = webdriver.PhantomJS()
    driver.get(url)
    
    # click season
    driver.find_element_by_css_selector('#cphContainer_cphContents_ddlSeason_ddlSeason').\
            find_elements_by_css_selector('option')[season_id].click()
    time.sleep(api_delay_term)
    # click team
    driver.find_element_by_css_selector('#cphContainer_cphContents_ddlTeam_ddlTeam').\
            find_elements_by_css_selector('option')[team_id].click()
    time.sleep(api_delay_term)
    elements = driver.find_elements_by_css_selector(".record_result tr")
    elements = elements[1:len(elements)+1]
    
    hitter_detail_df = pd.DataFrame(columns=[
        'rank', 'name', 'team', 'avg', 'xbh', 'go', 'ao', 'go/ao', 'gw rbi',
        'bb/k', 'p/pa', 'isop', 'xr', 'gpa'
    ])
    
    for element in elements:
        tmp_dict  = {
            'rank' : element.find_elements_by_css_selector('td')[0].text,
            'name' : element.find_elements_by_css_selector('td')[1].text,
            'team' : element.find_elements_by_css_selector('td')[2].text,
            'avg' : element.find_elements_by_css_selector('td')[3].text,
            'xbh' : element.find_elements_by_css_selector('td')[4].text,
            'go' : element.find_elements_by_css_selector('td')[5].text,
            'ao' : element.find_elements_by_css_selector('td')[6].text,
            'go/ao' : element.find_elements_by_css_selector('td')[7].text,
            'gw rbi' : element.find_elements_by_css_selector('td')[8].text,
            'bb/k' : element.find_elements_by_css_selector('td')[9].text,
            'p/pa' : element.find_elements_by_css_selector('td')[10].text,
            'isop' : element.find_elements_by_css_selector('td')[11].text,
            'xr' : element.find_elements_by_css_selector('td')[12].text,
            'gpa' : element.find_elements_by_css_selector('td')[13].text,
        }
        hitter_detail_df.loc[len(hitter_detail_df)] = tmp_dict
    return hitter_detail_df

# %%
crawling_hitter_detail(33,1)

# %%
# crawling_pitcher_basic
def crawling_pitcher_basic(season_id, team_id):
    """
    season_id = 0 ~ 34
    team_id = 1 ~ 10
    ------------------------------------------------------------------------------------
    <season_id>
    0 : 1982 
      :
      :
    34 : 2016
    
    <team_id>
    1 : Nexen heroes
    2 : Doosan
    3 : Lotte
    4 : Samsung
    5 : Hanhwa
    6 : KIA
    7 : KT
    8 : LG twins
    9 : NC dinos
    10 : SK wyberns
    """
    
    url = "http://www.koreabaseball.com/Record/Player/PitcherBasic/Basic1.aspx"
    driver = webdriver.PhantomJS()
    driver.get(url)
    
    # click season
    driver.find_element_by_css_selector('#cphContainer_cphContents_ddlSeason_ddlSeason').\
            find_elements_by_css_selector('option')[season_id].click()
    time.sleep(api_delay_term)
    # click team
    driver.find_element_by_css_selector('#cphContainer_cphContents_ddlTeam_ddlTeam').\
            find_elements_by_css_selector('option')[team_id].click()
    time.sleep(api_delay_term)
    elements = driver.find_elements_by_css_selector(".record_result tr")
    elements = elements[1:len(elements)+1]
    
    pitcher_basic_df = pd.DataFrame(columns=[
        'rank', 'name', 'team', 'ERA', 'G', 'W', 'L', 'SV', 'HLD', 'WPCT',
        '3b', 'hr', 'tb', 'rbi', 'sac', 'sf'
    ])
    
    for element in elements:
        tmp_dict  = {
            'rank' : element.find_elements_by_css_selector('td')[0].text,
            'name' : element.find_elements_by_css_selector('td')[1].text,
            'team' : element.find_elements_by_css_selector('td')[2].text,
            'avg' : element.find_elements_by_css_selector('td')[3].text,
            'g' : element.find_elements_by_css_selector('td')[4].text,
            'pa' : element.find_elements_by_css_selector('td')[5].text,
            'ab' : element.find_elements_by_css_selector('td')[6].text,
            'r' : element.find_elements_by_css_selector('td')[7].text,
            'h' : element.find_elements_by_css_selector('td')[8].text,
            '2b' : element.find_elements_by_css_selector('td')[9].text,
            '3b' : element.find_elements_by_css_selector('td')[10].text,
            'hr' : element.find_elements_by_css_selector('td')[11].text,
            'tb' : element.find_elements_by_css_selector('td')[12].text,
            'rbi' : element.find_elements_by_css_selector('td')[13].text,
            'sac' : element.find_elements_by_css_selector('td')[14].text,
            'sf' : element.find_elements_by_css_selector('td')[15].text,
        }
        pitcher_basic_df.loc[len(pitcher_basic_df)] = tmp_dict
    return pitcher_basic_df

# %%
nexen_15_df = crawling_pitcher_basic(33,1)

# %%
nexen_15_df.to_csv("nexen_15.csv",encoding='utf-8')

# %%
doosan_15_df = crawling_pitcher_basic(33,2)
lotte_15_df = crawling_pitcher_basic(33,3)
samsung_15_df = crawling_pitcher_basic(33,4)
hanhwa_15_df = crawling_pitcher_basic(33,5)
KIA_15_df = crawling_pitcher_basic(33,6)
KT_15_df = crawling_pitcher_basic(33,7)
LG_15_df = crawling_pitcher_basic(33,8)
NC_15_df = crawling_pitcher_basic(33,9)
SK_15_df = crawling_pitcher_basic(33,10)

# %%
doosan_15_df.to_csv("doosan_15.csv",encoding='utf-8')
lotte_15_df.to_csv("lotte_15.csv",encoding='utf-8')
samsung_15_df.to_csv("samsung_15.csv",encoding='utf-8')
hanhwa_15_df.to_csv("hanhwa_15.csv",encoding='utf-8')
KIA_15_df.to_csv("KIA_15.csv",encoding='utf-8')
KT_15_df.to_csv("KT_15.csv",encoding='utf-8')
LG_15_df.to_csv("LG_15.csv",encoding='utf-8')
NC_15_df.to_csv("NC_15.csv",encoding='utf-8')
SK_15_df.to_csv("SK_15.csv",encoding='utf-8')

# %%
SK_15_df
# Out:
#    rank name team    avg   g  pa  ab   r   h     2b       3b   hr  tb rbi sac  \
# 0     1  윤석주   SK   0.00   1   0   0   0   0      -    1 1/3    2   0   0   0
# 1     2  윤길현   SK   3.16  70   0   4  13  17  0.000   62 2/3   58   7  36   2
# 2     3  정우람   SK   3.21  69   7   5  16  11  0.583       70   52   3  28   1
# 3     4  김광현   SK   3.72  30  14   6   0   1  0.700  176 2/3  173  19  66   3
# 4     5  이한진   SK   3.86   3   0   0   0   0      -    4 2/3    4   0   5   0
# 5     6  신재웅   SK   4.11  61   0   1   0   9  0.000   50 1/3   72   5  17   4
# 6     7   켈리   SK   4.13  30  11  10   0   0  0.524      181  188  16  54   5
# 7     8  박민호   SK   4.28  20   1   1   0   1  0.500   27 1/3   26   4   9   2
# 8     9  전유수   SK   4.40  66   3   6   1   5  0.333   77 2/3   66   9  42   5
# 9    10  밴와트   SK   4.63  12   5   3   0   0  0.625   56 1/3   70   5  13   2
# 10   11  이재영   SK   4.65  26   1   0   0   1  1.000       31   36   4  13   3
# 11   12  백인식   SK   4.79   7   1   2   0   0  0.333   20 2/3   24   2  11   2
# 12   13   세든   SK   4.99  14   7   5   0   0  0.583       74   77  12  28   5
# 13   14  박종훈   SK   5.19  33   6   8   0   0  0.429      118  123   7  53  17
# 14   15  박정배   SK   5.33  24   2   2   0   2  0.500   25 1/3   25   3  13   2
# 15   16  박희수   SK   5.40  14   0   0   0   2      -       10   13   3   8   1
# 16   17  윤희상   SK   5.88  21   5   9   0   0  0.357   93 1/3  113  15  34   3
# 17   18  서진용   SK   5.91  18   0   0   0   0      -   21 1/3   25   4   6   0
# 18   19  이창욱   SK   6.00   2   0   0   0   0      -        3    2   0   2   0
# 19   20  채병용   SK   6.07  33   4   4   0   1  0.500       83  103  17  27   3
# 20   21  고효준   SK   6.18  30   0   3   0   0  0.000       51   61   8  31   4
# 21   22  문광은   SK   6.85  53   1   5   1  11  0.167   64 1/3   87  13  27   4
# 22   23  김태훈   SK  27.00   1   0   0   0   0      -      1/3    0   0   1   0
#
#      sf
# 0     0
# 1    62
# 2    90
# 3   160
# 4     1
# 5    49
# 6   139
# 7    12
# 8    84
# 9    50
# 10   26
# 11   14
# 12   67
# 13  105
# 14   28
# 15   12
# 16   67
# 17   24
# 18    1
# 19   78
# 20   43
# 21   54
# 22    0

# %%
# Crawling players salary

# %%
url = "http://www.koreabaseball.com/Record/Player/HitterBasic/Basic1.aspx"
driver = webdriver.PhantomJS()
driver.get(url)
driver.find_element_by_css_selector('#cphContainer_cphContents_ddlSeason_ddlSeason').\
            find_elements_by_css_selector('option')[33].click()
time.sleep(api_delay_term)
    # click team
driver.find_element_by_css_selector('#cphContainer_cphContents_ddlTeam_ddlTeam').\
            find_elements_by_css_selector('option')[1].click()

# %%
elements = driver.find_elements_by_css_selector(".record_result tr")
elements = elements[1:len(elements)+1]

# for element in elements:
player_url = elements[0].find_element_by_css_selector("a").get_attribute("href")

# %%
player_url
# Out:
# 'http://www.koreabaseball.com/Record/Player/HitterDetail/Basic.aspx?playerId=74339'

# %%
driver = webdriver.Firefox()
driver.get(player_url)

# %%
player_info = driver.find_elements_by_css_selector(".player_basic ul li")

# %%
def crawling_player_info(season_id, team_id):
    """
    season_id = 0 ~ 34
    team_id = 1 ~ 10
    ------------------------------------------------------------------------------------
    <season_id>
    0 : 1982 
      :
      :
    34 : 2016
    
    <team_id>
    1 : Nexen heroes
    2 : Doosan
    3 : Lotte
    4 : Samsung
    5 : Hanhwa
    6 : KIA
    7 : KT
    8 : LG twins
    9 : NC dinos
    10 : SK wyberns
    """
    
    # connect base_url
    url = "http://www.koreabaseball.com/Record/Player/HitterBasic/Basic1.aspx"
    driver = webdriver.PhantomJS()
    driver.get(url)
    
    # click season
    driver.find_element_by_css_selector('#cphContainer_cphContents_ddlSeason_ddlSeason').\
                find_elements_by_css_selector('option')[season_id].click()
#     time.sleep(api_delay_term)
    
    # click team
    driver.find_element_by_css_selector('#cphContainer_cphContents_ddlTeam_ddlTeam').\
                find_elements_by_css_selector('option')[team_id].click()
    
    # get players_url
    elements = driver.find_elements_by_css_selector(".record_result tr")
    elements = elements[1:len(elements)+1]
    player_info_df = pd.DataFrame(columns=[
                    "p_number", "name", "u_number", "birth", "position", "tall",
                    "weight", "career", "contract", "salary", "rank_nomi", "entry_yr"
            ])
    for element in elements:
        players_url = element.find_element_by_css_selector("a").get_attribute("href")
#         driver.swi
#        time.sleep(api_delay_term)
        player_info = driver.find_elements_by_css_selector(".player_basic ul li")
        
        print(players_url)
#         tmp_dict = {
#                     "p_number" : players_url.split("=")[1],
#                     "name" : player_info[0].text.split(": ")[1],
#                     "u_number" : player_info[1].text.split(": ")[1],
#                     "birth" : player_info[2].text.split(": ")[1],
#                     "position" : player_info[3].text.split(": ")[1],
#                     "tall" : player_info[4].text.split(": ")[1].split("/")[0],
#                     "weight" : player_info[4].text.split(": ")[1].split("/")[1],
#                     "career" : player_info[5].text.split(": ")[1],
#                     "contract" : player_info[6].text.split(": ")[1],
#                     "salary" : player_info[7].text.split(": ")[1],
#                     "rank_nomi" : player_info[8].text.split(": ")[1],
#                     "entry_yr" : player_info[9].text.split(": ")[1],
#             }
#         player_info_df.loc[len(player_info_df)] = tmp_dict
#     return player_info_df

# %%
crawling_player_info(33, 1)
# Out:
# http://www.koreabaseball.com/Record/Player/HitterDetail/Basic.aspx?playerId=72443
# http://www.koreabaseball.com/Record/Player/HitterDetail/Basic.aspx?playerId=76509
# http://www.koreabaseball.com/Record/Player/HitterDetail/Basic.aspx?playerId=64914
# http://www.koreabaseball.com/Record/Player/HitterDetail/Basic.aspx?playerId=74163
# http://www.koreabaseball.com/Record/Player/HitterDetail/Basic.aspx?playerId=65103
# http://www.koreabaseball.com/Record/Player/HitterDetail/Basic.aspx?playerId=62947
# http://www.koreabaseball.com/Record/Player/HitterDetail/Basic.aspx?playerId=78224
# http://www.koreabaseball.com/Record/Player/HitterDetail/Basic.aspx?playerId=76249
# http://www.koreabaseball.com/Record/Player/HitterDetail/Basic.aspx?playerId=70410
# http://www.koreabaseball.com/Record/Player/HitterDetail/Basic.aspx?playerId=79192
# http://www.koreabaseball.com/Record/Player/HitterDetail/Basic.aspx?playerId=72133
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-27-c75f94705a9e> in <module>()
# ----> 1 crawling_player_info(33, 1)
#
# <ipython-input-24-564ed7d653f1> in crawling_player_info(season_id, team_id)
#      43             ])
#      44     for element in elements:
# ---> 45         players_url = element.find_element_by_css_selector("a").get_attribute("href")
#      46 #         driver.swi
#      47 #        time.sleep(api_delay_term)
#
# /Users/Cho/.pyenv/versions/3.5.1/envs/dss/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py in find_element_by_css_selector(self, css_selector)
#     280             - css_selector - CSS selctor string, ex: 'a.nav#home'
#     281         """
# --> 282         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     283
#     284     def find_elements_by_css_selector(self, css_selector):
#
# /Users/Cho/.pyenv/versions/3.5.1/envs/dss/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py in find_element(self, by, value)
#     475
#     476         return self._execute(Command.FIND_CHILD_ELEMENT,
# --> 477                              {"using": by, "value": value})['value']
#     478
#     479     def find_elements(self, by=By.ID, value=None):
#
# /Users/Cho/.pyenv/versions/3.5.1/envs/dss/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     455             params = {}
#     456         params['id'] = self._id
# --> 457         return self._parent.execute(command, params)
#     458
#     459     def find_element(self, by=By.ID, value=None):
#
# /Users/Cho/.pyenv/versions/3.5.1/envs/dss/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     231         response = self.command_executor.execute(driver_command, params)
#     232         if response:
# --> 233             self.error_handler.check_response(response)
#     234             response['value'] = self._unwrap_value(
#     235                 response.get('value', None))
#
# /Users/Cho/.pyenv/versions/3.5.1/envs/dss/lib/python3.5/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     192         elif exception_class == UnexpectedAlertPresentException and 'alert' in value:
#     193             raise exception_class(message, screen, stacktrace, value['alert'].get('text'))
# --> 194         raise exception_class(message, screen, stacktrace)
#     195
#     196     def _value_or_default(self, obj, key, default):
#
# StaleElementReferenceException: Message: {"errorMessage":"Element does not exist in cache","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Connection":"close","Content-Length":"120","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:53248","User-Agent":"Python-urllib/3.5"},"httpVersion":"1.1","method":"POST","post":"{\"id\": \":wdc:1467337068774\", \"value\": \"a\", \"sessionId\": \"67918600-3f2c-11e6-95ef-6d5f790b9835\", \"using\": \"css selector\"}","url":"/element","urlParsed":{"anchor":"","query":"","file":"element","directory":"/","path":"/element","relative":"/element","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/element","queryKey":{},"chunks":["element"]},"urlOriginal":"/session/67918600-3f2c-11e6-95ef-6d5f790b9835/element/:wdc:1467337068774/element"}}
# Screenshot: available via screen
