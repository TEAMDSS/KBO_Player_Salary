# %%
import pandas as pd

# %%
doosan_hb_df = pd.read_csv("basic/doosan_hb_15.csv")
hanhwa_hb_df = pd.read_csv("basic/hanhwa_hb_15.csv")
KIA_hb_df = pd.read_csv("basic/KIA_hb_15.csv")
KT_hb_df = pd.read_csv("basic/KT_hb_15.csv")
LG_hb_df = pd.read_csv("basic/LG_hb_15.csv")
lotte_hb_df = pd.read_csv("basic/lotte_hb_15.csv")
NC_hb_df = pd.read_csv("basic/NC_hb_15.csv")
nexen_hb_df = pd.read_csv("basic/nexen_hb_15.csv")
samsung_hb_df = pd.read_csv("basic/samsung_hb_15.csv")
SK_hb_df = pd.read_csv("basic/SK_hb_15.csv")

# %%
doosan_hd_df = pd.read_csv("detail/doosan_hd_15.csv")
hanhwa_hd_df = pd.read_csv("detail/hanhwa_hd_15.csv")
KIA_hd_df = pd.read_csv("detail/KIA_hd_15.csv")
KT_hd_df = pd.read_csv("detail/KT_hd_15.csv")
LG_hd_df = pd.read_csv("detail/LG_hd_15.csv")
lotte_hd_df = pd.read_csv("detail/lotte_hd_15.csv")
NC_hd_df = pd.read_csv("detail/NC_hd_15.csv")
nexen_hd_df = pd.read_csv("detail/nexen_hd_15.csv")
samsung_hd_df = pd.read_csv("detail/samsung_hd_15.csv")
SK_hd_df = pd.read_csv("detail/SK_hd_15.csv")

# %%
doosan_d_df = pd.read_csv("../defense/doosan_d.csv")
hanhwa_d_df = pd.read_csv("../defense/hanhwa_d.csv")
KIA_d_df = pd.read_csv("../defense/KIA_d.csv")
KT_d_df = pd.read_csv("../defense/KT_d.csv")
LG_d_df = pd.read_csv("../defense/LG_d.csv")
lotte_d_df = pd.read_csv("../defense/lotte_d.csv")
NC_d_df = pd.read_csv("../defense/NC_d.csv")
nexen_d_df = pd.read_csv("../defense/nexen_d.csv")
samsung_d_df = pd.read_csv("../defense/samsung_d.csv")
SK_d_df = pd.read_csv("../defense/SK_d.csv")

# %%
doosan_r_df = pd.read_csv("../running/doosan_r.csv")
hanhwa_r_df = pd.read_csv("../running/hanhwa_r.csv")
KIA_r_df = pd.read_csv("../running/KIA_r.csv")
KT_r_df = pd.read_csv("../running/KT_r.csv")
LG_r_df = pd.read_csv("../running/LG_r.csv")
lotte_r_df = pd.read_csv("../running/lotte_r.csv")
NC_r_df = pd.read_csv("../running/NC_r.csv")
nexen_r_df = pd.read_csv("../running/nexen_r.csv")
samsung_r_df = pd.read_csv("../running/samsung_r.csv")
SK_r_df = pd.read_csv("../running/SK_r.csv")

# %%
doosan_df = doosan_hb_df.merge(doosan_hd_df, left_on="name",right_on="name")[["name", "team_x", "AVG_x", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA"]]
hanhwa_df = hanhwa_hb_df.merge(hanhwa_hd_df, left_on="name",right_on="name")[["name", "team_x", "AVG_x", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA"]]
KIA_df = KIA_hb_df.merge(KIA_hd_df, left_on="name",right_on="name")[["name", "team_x", "AVG_x", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA"]]
KT_df = KT_hb_df.merge(KT_hd_df, left_on="name",right_on="name")[["name", "team_x", "AVG_x", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA"]]
LG_df = LG_hb_df.merge(LG_hd_df, left_on="name",right_on="name")[["name", "team_x", "AVG_x", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA"]]
lotte_df = lotte_hb_df.merge(lotte_hd_df, left_on="name",right_on="name")[["name", "team_x", "AVG_x", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA"]]
NC_df = NC_hb_df.merge(NC_hd_df, left_on="name",right_on="name")[["name", "team_x", "AVG_x", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA"]]
nexen_df = nexen_hb_df.merge(nexen_hd_df, left_on="name",right_on="name")[["name", "team_x", "AVG_x", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA"]]
samsung_df = samsung_hb_df.merge(samsung_hd_df, left_on="name",right_on="name")[["name", "team_x", "AVG_x", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA"]]
SK_df = SK_hb_df.merge(SK_hd_df, left_on="name",right_on="name")[["name", "team_x", "AVG_x", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA"]]

# %%
doosan_df = doosan_df.rename(columns={"team_x":"team"})
hanhwa_df = hanhwa_df.rename(columns={"team_x":"team"})
KIA_df = KIA_df.rename(columns={"team_x":"team"})
KT_df = KT_df.rename(columns={"team_x":"team"})
LG_df = LG_df.rename(columns={"team_x":"team"})
lotte_df = lotte_df.rename(columns={"team_x":"team"})
NC_df = NC_df.rename(columns={"team_x":"team"})
nexen_df = nexen_df.rename(columns={"team_x":"team"})
samsung_df = samsung_df.rename(columns={"team_x":"team"})
SK_df = SK_df.rename(columns={"team_x":"team"})

# %%
doosan_df = doosan_df.rename(columns={"AVG_x":"AVG"})
hanhwa_df = hanhwa_df.rename(columns={"AVG_x":"AVG"})
KIA_df = KIA_df.rename(columns={"AVG_x":"AVG"})
KT_df = KT_df.rename(columns={"AVG_x":"AVG"})
LG_df = LG_df.rename(columns={"AVG_x":"AVG"})
lotte_df = lotte_df.rename(columns={"AVG_x":"AVG"})
NC_df = NC_df.rename(columns={"AVG_x":"AVG"})
nexen_df = nexen_df.rename(columns={"AVG_x":"AVG"})
samsung_df = samsung_df.rename(columns={"AVG_x":"AVG"})
SK_df = SK_df.rename(columns={"AVG_x":"AVG"})

# %%
doosan_df = doosan_df.merge(doosan_d_df, left_on="name",right_on="name")[["name", "team", "AVG", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA", "PO", "PKO", "IP", "DP", "GS", "A", "SB", "CS", "PB", "E", "FPCT", "CS%"]]
hanhwa_df = hanhwa_df.merge(hanhwa_d_df, left_on="name",right_on="name")[["name", "team", "AVG", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA", "PO", "PKO", "IP", "DP", "GS", "A", "SB", "CS", "PB", "E", "FPCT", "CS%"]]
KIA_df = KIA_df.merge(KIA_d_df, left_on="name",right_on="name")[["name", "team", "AVG", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA", "PO", "PKO", "IP", "DP", "GS", "A", "SB", "CS", "PB", "E", "FPCT", "CS%"]]
KT_df = KT_df.merge(KT_d_df, left_on="name",right_on="name")[["name", "team", "AVG", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA", "PO", "PKO", "IP", "DP", "GS", "A", "SB", "CS", "PB", "E", "FPCT", "CS%"]]
LG_df = LG_df.merge(LG_d_df, left_on="name",right_on="name")[["name", "team", "AVG", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA", "PO", "PKO", "IP", "DP", "GS", "A", "SB", "CS", "PB", "E", "FPCT", "CS%"]]
lotte_df = lotte_df.merge(lotte_d_df, left_on="name",right_on="name")[["name", "team", "AVG", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA", "PO", "PKO", "IP", "DP", "GS", "A", "SB", "CS", "PB", "E", "FPCT", "CS%"]]
NC_df = NC_df.merge(NC_d_df, left_on="name",right_on="name")[["name", "team", "AVG", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA", "PO", "PKO", "IP", "DP", "GS", "A", "SB", "CS", "PB", "E", "FPCT", "CS%"]]
nexen_df = nexen_df.merge(nexen_d_df, left_on="name",right_on="name")[["name", "team", "AVG", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA", "PO", "PKO", "IP", "DP", "GS", "A", "SB", "CS", "PB", "E", "FPCT", "CS%"]]
samsung_df = samsung_df.merge(samsung_d_df, left_on="name",right_on="name")[["name", "team", "AVG", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA", "PO", "PKO", "IP", "DP", "GS", "A", "SB", "CS", "PB", "E", "FPCT", "CS%"]]
SK_df = SK_df.merge(SK_d_df, left_on="name",right_on="name")[["name", "team", "AVG", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA", "PO", "PKO", "IP", "DP", "GS", "A", "SB", "CS", "PB", "E", "FPCT", "CS%"]]

# %%
doosan_df = doosan_df.merge(doosan_r_df, left_on="name",right_on="name")[["name", "team", "AVG", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA", "PO", "PKO", "IP", "DP", "GS", "A", "SB", "CS", "PB", "E", "FPCT", "CS%","SBA", "SB%", "OOB"]]
hanhwa_df = hanhwa_df.merge(hanhwa_r_df, left_on="name",right_on="name")[["name", "team", "AVG", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA", "PO", "PKO", "IP", "DP", "GS", "A", "SB", "CS", "PB", "E", "FPCT", "CS%","SBA", "SB%", "OOB"]]
KIA_df = KIA_df.merge(KIA_r_df, left_on="name",right_on="name")[["name", "team", "AVG", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA", "PO", "PKO", "IP", "DP", "GS", "A", "SB", "CS", "PB", "E", "FPCT", "CS%","SBA", "SB%", "OOB"]]
KT_df = KT_df.merge(KT_r_df, left_on="name",right_on="name")[["name", "team", "AVG", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA", "PO", "PKO", "IP", "DP", "GS", "A", "SB", "CS", "PB", "E", "FPCT", "CS%","SBA", "SB%", "OOB"]]
LG_df = LG_df.merge(LG_r_df, left_on="name",right_on="name")[["name", "team", "AVG", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA", "PO", "PKO", "IP", "DP", "GS", "A", "SB", "CS", "PB", "E", "FPCT", "CS%","SBA", "SB%", "OOB"]]
lotte_df = lotte_df.merge(lotte_r_df, left_on="name",right_on="name")[["name", "team", "AVG", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA", "PO", "PKO", "IP", "DP", "GS", "A", "SB", "CS", "PB", "E", "FPCT", "CS%","SBA", "SB%", "OOB"]]
NC_df = NC_df.merge(NC_r_df, left_on="name",right_on="name")[["name", "team", "AVG", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA", "PO", "PKO", "IP", "DP", "GS", "A", "SB", "CS", "PB", "E", "FPCT", "CS%","SBA", "SB%", "OOB"]]
nexen_df = nexen_df.merge(nexen_r_df, left_on="name",right_on="name")[["name", "team", "AVG", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA", "PO", "PKO", "IP", "DP", "GS", "A", "SB", "CS", "PB", "E", "FPCT", "CS%","SBA", "SB%", "OOB"]]
samsung_df = samsung_df.merge(samsung_r_df, left_on="name",right_on="name")[["name", "team", "AVG", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA", "PO", "PKO", "IP", "DP", "GS", "A", "SB", "CS", "PB", "E", "FPCT", "CS%","SBA", "SB%", "OOB"]]
SK_df = SK_df.merge(SK_r_df, left_on="name",right_on="name")[["name", "team", "AVG", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SAC", "SF", "XBH", "GO", "AO", "GO/AO", "GW_RBI", "BB/K", "P/PA", "ISOP", "XR", "GPA", "PO", "PKO", "IP", "DP", "GS", "A", "SB", "CS", "PB", "E", "FPCT", "CS%","SBA", "SB%", "OOB"]]

# %%
doosan_df.to_csv("doosan_hitter.csv",encoding='utf-8')
hanhwa_df.to_csv("hanhwa_hitter.csv",encoding='utf-8')
KIA_df.to_csv("KIA_hitter.csv",encoding='utf-8')
KT_df.to_csv("KT_hitter.csv",encoding='utf-8')
LG_df.to_csv("LG_hitter.csv",encoding='utf-8')
lotte_df.to_csv("lotte_hitter.csv",encoding='utf-8')
NC_df.to_csv("NC_hitter.csv",encoding='utf-8')
nexen_df.to_csv("nexen_hitter.csv",encoding='utf-8')
samsung_df.to_csv("samsung_hitter.csv",encoding='utf-8')
SK_df.to_csv("SK_hitter.csv",encoding='utf-8')

# %%
hitter_df = pd.concat([doosan_df, hanhwa_df, KIA_df, KT_df, LG_df, lotte_df, NC_df, nexen_df, samsung_df, SK_df]).reset_index(drop=True)

# %%
hitter_df.to_csv("hitter_final.csv",encoding='utf-8')

# %%
hitter_df
# Out:
#     name team    AVG    G   PA   AB    R    H  2B  3B ...     A  SB  CS  PB  \
# 0    박건우   두산  0.342   70  175  158   31   54  12   0 ...     2   0   0   0
# 1    김응민   두산  0.333    4    3    3    1    1   0   0 ...     0   0   0   0
# 2    고영민   두산  0.328   41   77   67   13   22   1   0 ...    25   0   0   0
# 3    김현수   두산  0.326  141  630  512  103  167  26   0 ...    13   0   0   0
# 4    양의지   두산  0.326  132  513  442   70  144  27   0 ...    76  93  33   4
# 5    허경민   두산  0.317  117  453  404   64  128  20   2 ...   246   0   0   0
# 6    김재호   두산  0.307  133  488  410   63  126  24   3 ...   352   0   0   0
# 7    민병헌   두산  0.303  129  561  491   80  149  20   2 ...     4   0   0   0
# 8    정수빈   두산  0.295  128  570  491   79  145  27   7 ...     4   0   0   0
# 9    오재일   두산  0.289   66  213  180   33   52  11   1 ...    27   0   0   0
# 10   최주환   두산  0.282  100  270  238   34   67  16   2 ...   125   0   0   0
# ...
